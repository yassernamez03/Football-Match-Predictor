# %%
import requests
import pandas as pd
import time

# %%
import requests
import pandas as pd
import time

BASE_URL = "https://www.thesportsdb.com/api/v1/json/3"
LEAGUE_ID = "4335"

def get_seasons(league_id):
    url = f"{BASE_URL}/search_all_seasons.php?id={league_id}"
    response = requests.get(url).json()
    return [season["strSeason"] for season in response.get("seasons", [])]

def get_round_matches(league_id, round_number, season):
    url = f"{BASE_URL}/eventsround.php?id={league_id}&r={round_number}&s={season}"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch data: {response.status_code}")
        return None
    data = response.json()
    events = data.get("events")
    if not events:  # Handles both None and empty list
        return None
    return events

def calculate_last_5_goals(team_matches, team):
    recent_matches = [m for m in team_matches if m.get("intHomeScore") is not None and m.get("intAwayScore") is not None]
    recent_matches = sorted(recent_matches, key=lambda m: int(m["intRound"]))[-5:]
    total_goals = 0
    for m in recent_matches:
        if m["strHomeTeam"] == team:
            total_goals += int(m["intHomeScore"])
        elif m["strAwayTeam"] == team:
            total_goals += int(m["intAwayScore"])
    return total_goals

def calculate_team_stats(team_matches, team):
    valid_matches = [m for m in team_matches if m.get("intHomeScore") is not None and m.get("intAwayScore") is not None]
    scored = 0
    conceded = 0
    wins = 0

    for m in valid_matches:
        hs = int(m["intHomeScore"])
        as_ = int(m["intAwayScore"])
        if m["strHomeTeam"] == team:
            scored += hs
            conceded += as_
            if hs > as_:
                wins += 1
        elif m["strAwayTeam"] == team:
            scored += as_
            conceded += hs
            if as_ > hs:
                wins += 1

    games_played = len(valid_matches)
    win_rate = wins / games_played if games_played else 0
    goal_diff = scored - conceded
    return scored, conceded, goal_diff, win_rate

def update_team_stats_post_round(matches, team_stats_tracker):
    for match in matches:
        home = match["strHomeTeam"]
        away = match["strAwayTeam"]
        hs = int(match["intHomeScore"])
        as_ = int(match["intAwayScore"])

        team_stats_tracker[home]["scored"] += hs
        team_stats_tracker[home]["conceded"] += as_
        team_stats_tracker[away]["scored"] += as_
        team_stats_tracker[away]["conceded"] += hs

        if hs > as_:
            team_stats_tracker[home]["pts"] += 3
            team_stats_tracker[home]["homeWins"] += 1
            team_stats_tracker[away]["awayLosses"] += 1
        elif hs < as_:
            team_stats_tracker[away]["pts"] += 3
            team_stats_tracker[away]["awayWins"] += 1
            team_stats_tracker[home]["homeLosses"] += 1
        else:
            team_stats_tracker[home]["pts"] += 1
            team_stats_tracker[away]["pts"] += 1
            team_stats_tracker[home]["homeDraws"] += 1
            team_stats_tracker[away]["awayDraws"] += 1

        team_stats_tracker[home]["GD"] = team_stats_tracker[home]["scored"] - team_stats_tracker[home]["conceded"]
        team_stats_tracker[away]["GD"] = team_stats_tracker[away]["scored"] - team_stats_tracker[away]["conceded"]

def calculate_rankings(team_stats_tracker):
    sorted_teams = sorted(
        team_stats_tracker.items(),
        key=lambda x: (x[1]["pts"], x[1]["GD"], x[1]["scored"]),
        reverse=True
    )
    for idx, (team, _) in enumerate(sorted_teams, start=1):
        team_stats_tracker[team]["rank"] = idx

def process_season(league_id, season):
    print(f"Processing season: {season}")

    teams = set()
    for round_number in [1, 2]:
        matches = get_round_matches(league_id, round_number, season)
        if matches is None:
            break
        for match in matches:
            teams.add(match.get("strHomeTeam"))
            teams.add(match.get("strAwayTeam"))

    teams = [t for t in teams if t]
    print(f"Teams in season: {len(teams)}")

    num_teams = len(teams)
    num_rounds = (num_teams - 1) * 2

    team_matches = {team: [] for team in teams}
    team_stats_tracker = {
        team: {
            "pts": 0, "scored": 0, "conceded": 0, "GD": 0, "rank": -1,
            "homeWins": 0, "homeDraws": 0, "homeLosses": 0,
            "awayWins": 0, "awayDraws": 0, "awayLosses": 0
        }
        for team in teams
    }

    data = []

    for round_number in range(1, num_rounds + 1):
        matches = get_round_matches(league_id, round_number, season)
        if matches is None:
            break
        time.sleep(0.5)

        valid_matches = []
        for match in matches:
            home_team = match.get("strHomeTeam")
            away_team = match.get("strAwayTeam")
            int_home_score = match.get("intHomeScore")
            int_away_score = match.get("intAwayScore")
            int_round = int(match.get("intRound", 0))

            if not all([home_team, away_team, int_home_score, int_away_score]):
                continue

            try:
                home_last5 = calculate_last_5_goals(team_matches[home_team], home_team)
                away_last5 = calculate_last_5_goals(team_matches[away_team], away_team)

                home_scored, home_conceded, home_gd, home_win_rate = calculate_team_stats(team_matches[home_team], home_team)
                away_scored, away_conceded, away_gd, away_win_rate = calculate_team_stats(team_matches[away_team], away_team)

                row = {
                "strLeague": match.get("strLeague"),
                "strSeason": season,
                "strHomeTeam": home_team,
                "strAwayTeam": away_team,
                "intHomeScore": int_home_score,
                "intAwayScore": int_away_score,
                "intRound": int_round,
                "homeScored": home_scored,
                "homeConceded": home_conceded,
                "homeGD": home_gd,
                "homeWinRate": home_win_rate,
                "awayScored": away_scored,
                "awayConceded": away_conceded,
                "awayGD": away_gd,
                "awayWinRate": away_win_rate,
                "homeClassement": team_stats_tracker[home_team]["rank"],
                "awayClassement": team_stats_tracker[away_team]["rank"],
                "lastHome5GamesScore": home_last5,
                "lastAway5GamesScore": away_last5,
                "homeWins": team_stats_tracker[home_team]["homeWins"],
                "homeDraws": team_stats_tracker[home_team]["homeDraws"],
                "homeLosses": team_stats_tracker[home_team]["homeLosses"],
                "awayWins": team_stats_tracker[away_team]["awayWins"],
                "awayDraws": team_stats_tracker[away_team]["awayDraws"],
                "awayLosses": team_stats_tracker[away_team]["awayLosses"]
                }

                data.append(row)
                print(row)
                valid_matches.append(match)
            except Exception as e:
                print(f"Error processing match: {match}")
                print(f"Error message: {e}")
                continue
        for match in valid_matches:
            team_matches[match["strHomeTeam"]].append(match)
            team_matches[match["strAwayTeam"]].append(match)

        update_team_stats_post_round(valid_matches, team_stats_tracker)

        if round_number > 0:
            calculate_rankings(team_stats_tracker)

    return pd.DataFrame(data)

def main():
    seasons = get_seasons(LEAGUE_ID)
    all_data = pd.DataFrame()

    for season in seasons:
        season_data = process_season(LEAGUE_ID, season)
        if season_data is None:
            continue
        all_data = pd.concat([all_data, season_data], ignore_index=True)

    all_data.to_csv("liga_data_with_home_away_stats.csv", index=False)
    print("Data saved to liga_data_with_home_away_stats.csv")

if __name__ == "__main__":
    main()
# Out:
# Processing season: 2002-2003
# Teams in season: 0
# Processing season: 2003-2004
# Teams in season: 0
# Processing season: 2004-2005
# Teams in season: 0
# Processing season: 2007-2008
# Teams in season: 0
# Processing season: 2008-2009
# Teams in season: 0
# Processing season: 2009-2010
# Teams in season: 0
# Processing season: 2010-2011
# Teams in season: 0
# Processing season: 2011-2012
# Teams in season: 0
# Processing season: 2012-2013
# Teams in season: 20
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Celta Vigo', 'strAwayTeam': 'Malaga', 'intHomeScore': '0', 'intAwayScore': '1', 'intRound': 1, 'homeScored': 0, 'homeConceded': 0, 'homeGD': 0, 'homeWinRate': 0, 'awayScored': 0, 'awayConceded': 0, 'awayGD': 0, 'awayWinRate': 0, 'homeClassement': -1, 'awayClassement': -1, 'lastHome5GamesScore': 0, 'lastAway5GamesScore': 0, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Sevilla', 'strAwayTeam': 'Getafe', 'intHomeScore': '2', 'intAwayScore': '1', 'intRound': 1, 'homeScored': 0, 'homeConceded': 0, 'homeGD': 0, 'homeWinRate': 0, 'awayScored': 0, 'awayConceded': 0, 'awayGD': 0, 'awayWinRate': 0, 'homeClassement': -1, 'awayClassement': -1, 'lastHome5GamesScore': 0, 'lastAway5GamesScore': 0, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Mallorca', 'strAwayTeam': 'Espanol', 'intHomeScore': '2', 'intAwayScore': '1', 'intRound': 1, 'homeScored': 0, 'homeConceded': 0, 'homeGD': 0, 'homeWinRate': 0, 'awayScored': 0, 'awayConceded': 0, 'awayGD': 0, 'awayWinRate': 0, 'homeClassement': -1, 'awayClassement': -1, 'lastHome5GamesScore': 0, 'lastAway5GamesScore': 0, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Real Madrid', 'strAwayTeam': 'Valencia', 'intHomeScore': '1', 'intAwayScore': '1', 'intRound': 1, 'homeScored': 0, 'homeConceded': 0, 'homeGD': 0, 'homeWinRate': 0, 'awayScored': 0, 'awayConceded': 0, 'awayGD': 0, 'awayWinRate': 0, 'homeClassement': -1, 'awayClassement': -1, 'lastHome5GamesScore': 0, 'lastAway5GamesScore': 0, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Ath Bilbao', 'strAwayTeam': 'Betis', 'intHomeScore': '3', 'intAwayScore': '5', 'intRound': 1, 'homeScored': 0, 'homeConceded': 0, 'homeGD': 0, 'homeWinRate': 0, 'awayScored': 0, 'awayConceded': 0, 'awayGD': 0, 'awayWinRate': 0, 'homeClassement': -1, 'awayClassement': -1, 'lastHome5GamesScore': 0, 'lastAway5GamesScore': 0, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Barcelona', 'strAwayTeam': 'Sociedad', 'intHomeScore': '5', 'intAwayScore': '1', 'intRound': 1, 'homeScored': 0, 'homeConceded': 0, 'homeGD': 0, 'homeWinRate': 0, 'awayScored': 0, 'awayConceded': 0, 'awayGD': 0, 'awayWinRate': 0, 'homeClassement': -1, 'awayClassement': -1, 'lastHome5GamesScore': 0, 'lastAway5GamesScore': 0, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Levante', 'strAwayTeam': 'Ath Madrid', 'intHomeScore': '1', 'intAwayScore': '1', 'intRound': 1, 'homeScored': 0, 'homeConceded': 0, 'homeGD': 0, 'homeWinRate': 0, 'awayScored': 0, 'awayConceded': 0, 'awayGD': 0, 'awayWinRate': 0, 'homeClassement': -1, 'awayClassement': -1, 'lastHome5GamesScore': 0, 'lastAway5GamesScore': 0, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'La Coruna', 'strAwayTeam': 'Osasuna', 'intHomeScore': '2', 'intAwayScore': '0', 'intRound': 1, 'homeScored': 0, 'homeConceded': 0, 'homeGD': 0, 'homeWinRate': 0, 'awayScored': 0, 'awayConceded': 0, 'awayGD': 0, 'awayWinRate': 0, 'homeClassement': -1, 'awayClassement': -1, 'lastHome5GamesScore': 0, 'lastAway5GamesScore': 0, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Vallecano', 'strAwayTeam': 'Granada', 'intHomeScore': '1', 'intAwayScore': '0', 'intRound': 1, 'homeScored': 0, 'homeConceded': 0, 'homeGD': 0, 'homeWinRate': 0, 'awayScored': 0, 'awayConceded': 0, 'awayGD': 0, 'awayWinRate': 0, 'homeClassement': -1, 'awayClassement': -1, 'lastHome5GamesScore': 0, 'lastAway5GamesScore': 0, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Zaragoza', 'strAwayTeam': 'Valladolid', 'intHomeScore': '0', 'intAwayScore': '1', 'intRound': 1, 'homeScored': 0, 'homeConceded': 0, 'homeGD': 0, 'homeWinRate': 0, 'awayScored': 0, 'awayConceded': 0, 'awayGD': 0, 'awayWinRate': 0, 'homeClassement': -1, 'awayClassement': -1, 'lastHome5GamesScore': 0, 'lastAway5GamesScore': 0, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Sociedad', 'strAwayTeam': 'Celta Vigo', 'intHomeScore': '2', 'intAwayScore': '1', 'intRound': 2, 'homeScored': 1, 'homeConceded': 5, 'homeGD': -4, 'homeWinRate': 0.0, 'awayScored': 0, 'awayConceded': 1, 'awayGD': -1, 'awayWinRate': 0.0, 'homeClassement': 20, 'awayClassement': 17, 'lastHome5GamesScore': 1, 'lastAway5GamesScore': 0, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Espanol', 'strAwayTeam': 'Zaragoza', 'intHomeScore': '1', 'intAwayScore': '2', 'intRound': 2, 'homeScored': 1, 'homeConceded': 2, 'homeGD': -1, 'homeWinRate': 0.0, 'awayScored': 0, 'awayConceded': 1, 'awayGD': -1, 'awayWinRate': 0.0, 'homeClassement': 13, 'awayClassement': 16, 'lastHome5GamesScore': 1, 'lastAway5GamesScore': 0, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Betis', 'strAwayTeam': 'Vallecano', 'intHomeScore': '1', 'intAwayScore': '2', 'intRound': 2, 'homeScored': 5, 'homeConceded': 3, 'homeGD': 2, 'homeWinRate': 1.0, 'awayScored': 1, 'awayConceded': 0, 'awayGD': 1, 'awayWinRate': 1.0, 'homeClassement': 2, 'awayClassement': 6, 'lastHome5GamesScore': 5, 'lastAway5GamesScore': 1, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Malaga', 'strAwayTeam': 'Mallorca', 'intHomeScore': '1', 'intAwayScore': '1', 'intRound': 2, 'homeScored': 1, 'homeConceded': 0, 'homeGD': 1, 'homeWinRate': 1.0, 'awayScored': 2, 'awayConceded': 1, 'awayGD': 1, 'awayWinRate': 1.0, 'homeClassement': 7, 'awayClassement': 5, 'lastHome5GamesScore': 1, 'lastAway5GamesScore': 2, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Osasuna', 'strAwayTeam': 'Barcelona', 'intHomeScore': '1', 'intAwayScore': '2', 'intRound': 2, 'homeScored': 0, 'homeConceded': 2, 'homeGD': -2, 'homeWinRate': 0.0, 'awayScored': 5, 'awayConceded': 1, 'awayGD': 4, 'awayWinRate': 1.0, 'homeClassement': 19, 'awayClassement': 1, 'lastHome5GamesScore': 0, 'lastAway5GamesScore': 5, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Getafe', 'strAwayTeam': 'Real Madrid', 'intHomeScore': '2', 'intAwayScore': '1', 'intRound': 2, 'homeScored': 1, 'homeConceded': 2, 'homeGD': -1, 'homeWinRate': 0.0, 'awayScored': 1, 'awayConceded': 1, 'awayGD': 0, 'awayWinRate': 0.0, 'homeClassement': 14, 'awayClassement': 9, 'lastHome5GamesScore': 1, 'lastAway5GamesScore': 1, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Granada', 'strAwayTeam': 'Sevilla', 'intHomeScore': '1', 'intAwayScore': '1', 'intRound': 2, 'homeScored': 0, 'homeConceded': 1, 'homeGD': -1, 'homeWinRate': 0.0, 'awayScored': 2, 'awayConceded': 1, 'awayGD': 1, 'awayWinRate': 1.0, 'homeClassement': 15, 'awayClassement': 4, 'lastHome5GamesScore': 0, 'lastAway5GamesScore': 2, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Valencia', 'strAwayTeam': 'La Coruna', 'intHomeScore': '3', 'intAwayScore': '3', 'intRound': 2, 'homeScored': 1, 'homeConceded': 1, 'homeGD': 0, 'homeWinRate': 0.0, 'awayScored': 2, 'awayConceded': 0, 'awayGD': 2, 'awayWinRate': 1.0, 'homeClassement': 11, 'awayClassement': 3, 'lastHome5GamesScore': 1, 'lastAway5GamesScore': 2, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Valladolid', 'strAwayTeam': 'Levante', 'intHomeScore': '2', 'intAwayScore': '0', 'intRound': 2, 'homeScored': 1, 'homeConceded': 0, 'homeGD': 1, 'homeWinRate': 1.0, 'awayScored': 1, 'awayConceded': 1, 'awayGD': 0, 'awayWinRate': 0.0, 'homeClassement': 8, 'awayClassement': 10, 'lastHome5GamesScore': 1, 'lastAway5GamesScore': 1, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Ath Madrid', 'strAwayTeam': 'Ath Bilbao', 'intHomeScore': '4', 'intAwayScore': '0', 'intRound': 2, 'homeScored': 1, 'homeConceded': 1, 'homeGD': 0, 'homeWinRate': 0.0, 'awayScored': 3, 'awayConceded': 5, 'awayGD': -2, 'awayWinRate': 0.0, 'homeClassement': 12, 'awayClassement': 18, 'lastHome5GamesScore': 1, 'lastAway5GamesScore': 3, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Celta Vigo', 'strAwayTeam': 'Osasuna', 'intHomeScore': '2', 'intAwayScore': '0', 'intRound': 3, 'homeScored': 1, 'homeConceded': 3, 'homeGD': -2, 'homeWinRate': 0.0, 'awayScored': 1, 'awayConceded': 4, 'awayGD': -3, 'awayWinRate': 0.0, 'homeClassement': 18, 'awayClassement': 19, 'lastHome5GamesScore': 1, 'lastAway5GamesScore': 1, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 1, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 1}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Zaragoza', 'strAwayTeam': 'Malaga', 'intHomeScore': '0', 'intAwayScore': '1', 'intRound': 3, 'homeScored': 2, 'homeConceded': 2, 'homeGD': 0, 'homeWinRate': 0.5, 'awayScored': 2, 'awayConceded': 1, 'awayGD': 1, 'awayWinRate': 0.5, 'homeClassement': 11, 'awayClassement': 8, 'lastHome5GamesScore': 2, 'lastAway5GamesScore': 2, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 1, 'awayWins': 1, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'La Coruna', 'strAwayTeam': 'Getafe', 'intHomeScore': '1', 'intAwayScore': '1', 'intRound': 3, 'homeScored': 5, 'homeConceded': 3, 'homeGD': 2, 'homeWinRate': 0.5, 'awayScored': 3, 'awayConceded': 3, 'awayGD': 0, 'awayWinRate': 0.5, 'homeClassement': 5, 'awayClassement': 10, 'lastHome5GamesScore': 5, 'lastAway5GamesScore': 3, 'homeWins': 1, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 1}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Mallorca', 'strAwayTeam': 'Sociedad', 'intHomeScore': '1', 'intAwayScore': '0', 'intRound': 3, 'homeScored': 3, 'homeConceded': 2, 'homeGD': 1, 'homeWinRate': 0.5, 'awayScored': 3, 'awayConceded': 6, 'awayGD': -3, 'awayWinRate': 0.5, 'homeClassement': 7, 'awayClassement': 12, 'lastHome5GamesScore': 3, 'lastAway5GamesScore': 3, 'homeWins': 1, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 1}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Vallecano', 'strAwayTeam': 'Sevilla', 'intHomeScore': '0', 'intAwayScore': '0', 'intRound': 3, 'homeScored': 3, 'homeConceded': 1, 'homeGD': 2, 'homeWinRate': 1.0, 'awayScored': 3, 'awayConceded': 2, 'awayGD': 1, 'awayWinRate': 0.5, 'homeClassement': 3, 'awayClassement': 6, 'lastHome5GamesScore': 3, 'lastAway5GamesScore': 3, 'homeWins': 1, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 1, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Ath Bilbao', 'strAwayTeam': 'Valladolid', 'intHomeScore': '2', 'intAwayScore': '0', 'intRound': 3, 'homeScored': 3, 'homeConceded': 9, 'homeGD': -6, 'homeWinRate': 0.0, 'awayScored': 3, 'awayConceded': 0, 'awayGD': 3, 'awayWinRate': 1.0, 'homeClassement': 20, 'awayClassement': 2, 'lastHome5GamesScore': 3, 'lastAway5GamesScore': 3, 'homeWins': 0, 'homeDraws': 0, 'homeLosses': 1, 'awayWins': 1, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Levante', 'strAwayTeam': 'Espanol', 'intHomeScore': '3', 'intAwayScore': '2', 'intRound': 3, 'homeScored': 1, 'homeConceded': 3, 'homeGD': -2, 'homeWinRate': 0.0, 'awayScored': 2, 'awayConceded': 4, 'awayGD': -2, 'awayWinRate': 0.0, 'homeClassement': 16, 'awayClassement': 17, 'lastHome5GamesScore': 1, 'lastAway5GamesScore': 2, 'homeWins': 0, 'homeDraws': 1, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 1}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Real Madrid', 'strAwayTeam': 'Granada', 'intHomeScore': '3', 'intAwayScore': '0', 'intRound': 3, 'homeScored': 2, 'homeConceded': 3, 'homeGD': -1, 'homeWinRate': 0.0, 'awayScored': 1, 'awayConceded': 2, 'awayGD': -1, 'awayWinRate': 0.0, 'homeClassement': 14, 'awayClassement': 15, 'lastHome5GamesScore': 2, 'lastAway5GamesScore': 1, 'homeWins': 0, 'homeDraws': 1, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 1}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Barcelona', 'strAwayTeam': 'Valencia', 'intHomeScore': '1', 'intAwayScore': '0', 'intRound': 3, 'homeScored': 7, 'homeConceded': 2, 'homeGD': 5, 'homeWinRate': 1.0, 'awayScored': 4, 'awayConceded': 4, 'awayGD': 0, 'awayWinRate': 0.0, 'homeClassement': 1, 'awayClassement': 13, 'lastHome5GamesScore': 7, 'lastAway5GamesScore': 4, 'homeWins': 1, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 1, 'awayLosses': 0}
# Error processing match: {'idEvent': '454652', 'idAPIfootball': None, 'strEvent': 'Betis vs Atletico Madrid', 'strEventAlternate': 'Atletico Madrid @ Betis', 'strFilename': 'Spanish La Liga 2012-09-26 Betis vs Atletico Madrid', 'strSport': 'Soccer', 'idLeague': '4335', 'strLeague': 'Spanish La Liga', 'strLeagueBadge': 'https://r2.thesportsdb.com/images/media/league/badge/ja4it51687628717.png', 'strSeason': '2012-2013', 'strDescriptionEN': None, 'strHomeTeam': 'Betis', 'strAwayTeam': 'Atletico Madrid', 'intHomeScore': '2', 'intRound': '3', 'intAwayScore': '4', 'intSpectators': '33196', 'strOfficial': None, 'strTimestamp': None, 'dateEvent': '2012-09-26', 'dateEventLocal': None, 'strTime': '18:00:00+00:00', 'strTimeLocal': None, 'strGroup': None, 'idHomeTeam': '133722', 'strHomeTeamBadge': None, 'idAwayTeam': '133729', 'strAwayTeamBadge': None, 'intScore': None, 'intScoreVotes': None, 'strResult': None, 'idVenue': None, 'strVenue': None, 'strCountry': None, 'strCity': None, 'strPoster': None, 'strSquare': None, 'strFanart': None, 'strThumb': None, 'strBanner': None, 'strMap': None, 'strTweet1': None, 'strTweet2': None, 'strTweet3': None, 'strVideo': None, 'strStatus': None, 'strPostponed': 'no', 'strLocked': 'unlocked'}
# Error message: 'Atletico Madrid'
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Malaga', 'strAwayTeam': 'Levante', 'intHomeScore': '3', 'intAwayScore': '1', 'intRound': 4, 'homeScored': 3, 'homeConceded': 1, 'homeGD': 2, 'homeWinRate': 0.6666666666666666, 'awayScored': 4, 'awayConceded': 5, 'awayGD': -1, 'awayWinRate': 0.3333333333333333, 'homeClassement': 4, 'awayClassement': 11, 'lastHome5GamesScore': 3, 'lastAway5GamesScore': 4, 'homeWins': 0, 'homeDraws': 1, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 1}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Valencia', 'strAwayTeam': 'Celta Vigo', 'intHomeScore': '2', 'intAwayScore': '1', 'intRound': 4, 'homeScored': 4, 'homeConceded': 5, 'homeGD': -1, 'homeWinRate': 0.0, 'awayScored': 3, 'awayConceded': 3, 'awayGD': 0, 'awayWinRate': 0.3333333333333333, 'homeClassement': 17, 'awayClassement': 13, 'lastHome5GamesScore': 4, 'lastAway5GamesScore': 3, 'homeWins': 0, 'homeDraws': 1, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 1}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Getafe', 'strAwayTeam': 'Barcelona', 'intHomeScore': '1', 'intAwayScore': '4', 'intRound': 4, 'homeScored': 4, 'homeConceded': 4, 'homeGD': 0, 'homeWinRate': 0.3333333333333333, 'awayScored': 8, 'awayConceded': 2, 'awayGD': 6, 'awayWinRate': 1.0, 'homeClassement': 10, 'awayClassement': 1, 'lastHome5GamesScore': 4, 'lastAway5GamesScore': 8, 'homeWins': 1, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 1, 'awayDraws': 0, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Sevilla', 'strAwayTeam': 'Real Madrid', 'intHomeScore': '1', 'intAwayScore': '0', 'intRound': 4, 'homeScored': 3, 'homeConceded': 2, 'homeGD': 1, 'homeWinRate': 0.3333333333333333, 'awayScored': 5, 'awayConceded': 3, 'awayGD': 2, 'awayWinRate': 0.3333333333333333, 'homeClassement': 7, 'awayClassement': 9, 'lastHome5GamesScore': 3, 'lastAway5GamesScore': 5, 'homeWins': 1, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 1}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': '
 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Zaragoza', 'strAwayTeam': 'Sevilla', 'intHomeScore': '2', 'intAwayScore': '1', 'intRound': 9, 'homeScored': 7, 'homeConceded': 7, 'homeGD': 0, 'homeWinRate': 0.5, 'awayScored': 9, 'awayConceded': 6, 'awayGD': 3, 'awayWinRate': 0.5714285714285714, 'homeClassement': 10, 'awayClassement': 4, 'lastHome5GamesScore': 7, 'lastAway5GamesScore': 6, 'homeWins': 1, 'homeDraws': 0, 'homeLosses': 2, 'awayWins': 1, 'awayDraws': 2, 'awayLosses': 1}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Levante', 'strAwayTeam': 'Granada', 'intHomeScore': '3', 'intAwayScore': '1', 'intRound': 9, 'homeScored': 9, 'homeConceded': 13, 'homeGD': -4, 'homeWinRate': 0.5, 'awayScored': 7, 'awayConceded': 12, 'awayGD': -5, 'awayWinRate': 0.25, 'homeClassement': 5, 'awayClassement': 14, 'lastHome5GamesScore': 5, 'lastAway5GamesScore': 6, 'homeWins': 3, 'homeDraws': 1, 'homeLosses': 0, 'awayWins': 1, 'awayDraws': 0, 'awayLosses': 3}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Ath Bilbao', 'strAwayTeam': 'Getafe', 'intHomeScore': '1', 'intAwayScore': '2', 'intRound': 9, 'homeScored': 11, 'homeConceded': 15, 'homeGD': -4, 'homeWinRate': 0.2857142857142857, 'awayScored': 6, 'awayConceded': 11, 'awayGD': -5, 'awayWinRate': 0.16666666666666666, 'homeClassement': 13, 'awayClassement': 20, 'lastHome5GamesScore': 8, 'lastAway5GamesScore': 5, 'homeWins': 2, 'homeDraws': 1, 'homeLosses': 1, 'awayWins': 0, 'awayDraws': 1, 'awayLosses': 2}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Ath Madrid', 'strAwayTeam': 'Osasuna', 'intHomeScore': '3', 'intAwayScore': '1', 'intRound': 9, 'homeScored': 15, 'homeConceded': 6, 'homeGD': 9, 'homeWinRate': 0.8571428571428571, 'awayScored': 7, 'awayConceded': 11, 'awayGD': -4, 'awayWinRate': 0.125, 'homeClassement': 2, 'awayClassement': 18, 'lastHome5GamesScore': 10, 'lastAway5GamesScore': 6, 'homeWins': 4, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 4}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Mallorca', 'strAwayTeam': 'Real Madrid', 'intHomeScore': '0', 'intAwayScore': '5', 'intRound': 9, 'homeScored': 10, 'homeConceded': 8, 'homeGD': 2, 'homeWinRate': 0.42857142857142855, 'awayScored': 14, 'awayConceded': 7, 'awayGD': 7, 'awayWinRate': 0.42857142857142855, 'homeClassement': 7, 'awayClassement': 6, 'lastHome5GamesScore': 7, 'lastAway5GamesScore': 12, 'homeWins': 3, 'homeDraws': 0, 'homeLosses': 1, 'awayWins': 0, 'awayDraws': 1, 'awayLosses': 2}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Valladolid', 'strAwayTeam': 'Sociedad', 'intHomeScore': '2', 'intAwayScore': '2', 'intRound': 9, 'homeScored': 11, 'homeConceded': 8, 'homeGD': 3, 'homeWinRate': 0.42857142857142855, 'awayScored': 6, 'awayConceded': 10, 'awayGD': -4, 'awayWinRate': 0.3333333333333333, 'homeClassement': 9, 'awayClassement': 16, 'lastHome5GamesScore': 8, 'lastAway5GamesScore': 5, 'homeWins': 2, 'homeDraws': 0, 'homeLosses': 1, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 3}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Malaga', 'strAwayTeam': 'Vallecano', 'intHomeScore': '1', 'intAwayScore': '2', 'intRound': 10, 'homeScored': 9, 'homeConceded': 5, 'homeGD': 4, 'homeWinRate': 0.5, 'awayScored': 9, 'awayConceded': 19, 'awayGD': -10, 'awayWinRate': 0.2857142857142857, 'homeClassement': 4, 'awayClassement': 18, 'lastHome5GamesScore': 6, 'lastAway5GamesScore': 6, 'homeWins': 2, 'homeDraws': 1, 'homeLosses': 0, 'awayWins': 1, 'awayDraws': 0, 'awayLosses': 3}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Real Madrid', 'strAwayTeam': 'Zaragoza', 'intHomeScore': '4', 'intAwayScore': '0', 'intRound': 10, 'homeScored': 19, 'homeConceded': 7, 'homeGD': 12, 'homeWinRate': 0.5, 'awayScored': 9, 'awayConceded': 8, 'awayGD': 1, 'awayWinRate': 0.5714285714285714, 'homeClassement': 5, 'awayClassement': 8, 'lastHome5GamesScore': 14, 'lastAway5GamesScore': 7, 'homeWins': 3, 'homeDraws': 1, 'homeLosses': 0, 'awayWins': 2, 'awayDraws': 0, 'awayLosses': 1}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Valencia', 'strAwayTeam': 'Ath Madrid', 'intHomeScore': '2', 'intAwayScore': '0', 'intRound': 10, 'homeScored': 9, 'homeConceded': 12, 'homeGD': -3, 'homeWinRate': 0.25, 'awayScored': 18, 'awayConceded': 7, 'awayGD': 11, 'awayWinRate': 0.875, 'homeClassement': 12, 'awayClassement': 2, 'lastHome5GamesScore': 5, 'lastAway5GamesScore': 9, 'homeWins': 2, 'homeDraws': 1, 'homeLosses': 0, 'awayWins': 2, 'awayDraws': 1, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Sociedad', 'strAwayTeam': 'Espanol', 'intHomeScore': '0', 'intAwayScore': '1', 'intRound': 10, 'homeScored': 8, 'homeConceded': 12, 'homeGD': -4, 'homeWinRate': 0.2857142857142857, 'awayScored': 10, 'awayConceded': 14, 'awayGD': -4, 'awayWinRate': 0.125, 'homeClassement': 15, 'awayClassement': 19, 'lastHome5GamesScore': 5, 'lastAway5GamesScore': 6, 'homeWins': 2, 'homeDraws': 0, 'homeLosses': 1, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 3}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'La Coruna', 'strAwayTeam': 'Mallorca', 'intHomeScore': '1', 'intAwayScore': '0', 'intRound': 10, 'homeScored': 13, 'homeConceded': 18, 'homeGD': -5, 'homeWinRate': 0.125, 'awayScored': 10, 'awayConceded': 13, 'awayGD': -3, 'awayWinRate': 0.375, 'homeClassement': 17, 'awayClassement': 9, 'lastHome5GamesScore': 7, 'lastAway5GamesScore': 6, 'homeWins': 1, 'homeDraws': 1, 'homeLosses': 2, 'awayWins': 0, 'awayDraws': 2, 'awayLosses': 1}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Osasuna', 'strAwayTeam': 'Valladolid', 'intHomeScore': '0', 'intAwayScore': '1', 'intRound': 10, 'homeScored': 8, 'homeConceded': 14, 'homeGD': -6, 'homeWinRate': 0.1111111111111111, 'awayScored': 13, 'awayConceded': 10, 'awayGD': 3, 'awayWinRate': 0.375, 'homeClassement': 20, 'awayClassement': 10, 'lastHome5GamesScore': 6, 'lastAway5GamesScore': 10, 'homeWins': 1, 'homeDraws': 2, 'homeLosses': 1, 'awayWins': 1, 'awayDraws': 0, 'awayLosses': 3}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Granada', 'strAwayTeam': 'Ath Bilbao', 'intHomeScore': '1', 'intAwayScore': '2', 'intRound': 10, 'homeScored': 8, 'homeConceded': 15, 'homeGD': -7, 'homeWinRate': 0.2222222222222222, 'awayScored': 12, 'awayConceded': 17, 'awayGD': -5, 'awayWinRate': 0.25, 'homeClassement': 14, 'awayClassement': 13, 'lastHome5GamesScore': 6, 'lastAway5GamesScore': 7, 'homeWins': 1, 'homeDraws': 2, 'homeLosses': 1, 'awayWins': 0, 'awayDraws': 1, 'awayLosses': 2}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Sevilla', 'strAwayTeam': 'Levante', 'intHomeScore': '0', 'intAwayScore': '0', 'intRound': 10, 'homeScored': 10, 'homeConceded': 8, 'homeGD': 2, 'homeWinRate': 0.5, 'awayScored': 12, 'awayConceded': 14, 'awayGD': -2, 'awayWinRate': 0.5555555555555556, 'homeClassement': 6, 'awayClassement': 3, 'lastHome5GamesScore': 7, 'lastAway5GamesScore': 7, 'homeWins': 3, 'homeDraws': 0, 'homeLosses': 0, 'awayWins': 1, 'awayDraws': 0, 'awayLosses': 3}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Getafe', 'strAwayTeam': 'Betis', 'intHomeScore': '2', 'intAwayScore': '4', 'intRound': 10, 'homeScored': 8, 'homeConceded': 12, 'homeGD': -4, 'homeWinRate': 0.2857142857142857, 'awayScored': 9, 'awayConceded': 5, 'awayGD': 4, 'awayWinRate': 0.6666666666666666, 'homeClassement': 16, 'awayClassement': 7, 'lastHome5GamesScore': 5, 'lastAway5GamesScore': 4, 'homeWins': 1, 'homeDraws': 0, 'homeLosses': 2, 'awayWins': 2, 'awayDraws': 1, 'awayLosses': 0}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Betis', 'strAwayTeam': 'Granada', 'intHomeScore': '1', 'intAwayScore': '2', 'intRound': 11, 'homeScored': 13, 'homeConceded': 7, 'homeGD': 6, 'homeWinRate': 0.7142857142857143, 'awayScored': 9, 'awayConceded': 17, 'awayGD': -8, 'awayWinRate': 0.2, 'homeClassement': 5, 'awayClassement': 17, 'lastHome5GamesScore': 7, 'lastAway5GamesScore': 7, 'homeWins': 2, 'homeDraws': 0, 'homeLosses': 1, 'awayWins': 1, 'awayDraws': 0, 'awayLosses': 4}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2012-2013', 'strHomeTeam': 'Vallecano', 'strAwayTeam': 'Celta Vigo', 'intHomeScore': '3', 'intAwayScore': '2', 'intRound': 11, 'homeScored': 11, 'homeConceded': 20, 'homeGD': -9, 'homeWinRate': 0.375, 'awayScored': 10, 'awayConceded': 11, 'awayGD': -1, 'awayWinRate': 0.3333333333333333, 'homeClassement': 15, 'awayClassement': 13, 'lastHome5GamesScore': 8, 'lastAway5GamesScore': 6, 'homeWins': 1, 'homeDraws': 1, 'homeLosses': 1, 'awayWins': 0, 'awayDraws': 0, 'awayLosses': 4}
# ...
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Osasuna', 'strAwayTeam': 'Getafe', 'intHomeScore': '1', 'intAwayScore': '2', 'intRound': 28, 'homeScored': 32, 'homeConceded': 40, 'homeGD': -8, 'homeWinRate': 0.25925925925925924, 'awayScored': 23, 'awayConceded': 22, 'awayGD': 1, 'awayWinRate': 0.2962962962962963, 'homeClassement': 14, 'awayClassement': 12, 'lastHome5GamesScore': 5, 'lastAway5GamesScore': 6, 'homeWins': 6, 'homeDraws': 6, 'homeLosses': 2, 'awayWins': 4, 'awayDraws': 2, 'awayLosses': 7}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Real Sociedad', 'strAwayTeam': 'Valladolid', 'intHomeScore': '2', 'intAwayScore': '1', 'intRound': 29, 'homeScored': 25, 'homeConceded': 30, 'homeGD': -5, 'homeWinRate': 0.35714285714285715, 'awayScored': 18, 'awayConceded': 63, 'awayGD': -45, 'awayWinRate': 0.14285714285714285, 'homeClassement': 12, 'awayClassement': 20, 'lastHome5GamesScore': 5, 'lastAway5GamesScore': 3, 'homeWins': 6, 'homeDraws': 2, 'homeLosses': 6, 'awayWins': 1, 'awayDraws': 0, 'awayLosses': 13}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Alaves', 'strAwayTeam': 'Vallecano', 'intHomeScore': '0', 'intAwayScore': '2', 'intRound': 29, 'homeScored': 32, 'homeConceded': 42, 'homeGD': -10, 'homeWinRate': 0.21428571428571427, 'awayScored': 31, 'awayConceded': 31, 'awayGD': 0, 'awayWinRate': 0.32142857142857145, 'homeClassement': 17, 'awayClassement': 9, 'lastHome5GamesScore': 7, 'lastAway5GamesScore': 4, 'homeWins': 4, 'homeDraws': 4, 'homeLosses': 5, 'awayWins': 4, 'awayDraws': 5, 'awayLosses': 5}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Real Madrid', 'strAwayTeam': 'Leganes', 'intHomeScore': '3', 'intAwayScore': '2', 'intRound': 29, 'homeScored': 59, 'homeConceded': 27, 'homeGD': 32, 'homeWinRate': 0.6428571428571429, 'awayScored': 26, 'awayConceded': 43, 'awayGD': -17, 'awayWinRate': 0.21428571428571427, 'homeClassement': 2, 'awayClassement': 18, 'lastHome5GamesScore': 8, 'lastAway5GamesScore': 7, 'homeWins': 11, 'homeDraws': 1, 'homeLosses': 1, 'awayWins': 1, 'awayDraws': 7, 'awayLosses': 6}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Espanyol', 'strAwayTeam': 'Atletico Madrid', 'intHomeScore': '1', 'intAwayScore': '1', 'intRound': 29, 'homeScored': 26, 'homeConceded': 39, 'homeGD': -13, 'homeWinRate': 0.25925925925925924, 'awayScored': 46, 'awayConceded': 22, 'awayGD': 24, 'awayWinRate': 0.5714285714285714, 'homeClassement': 15, 'awayClassement': 3, 'lastHome5GamesScore': 5, 'lastAway5GamesScore': 8, 'homeWins': 6, 'homeDraws': 5, 'homeLosses': 3, 'awayWins': 6, 'awayDraws': 4, 'awayLosses': 3}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Athletic Bilbao', 'strAwayTeam': 'Osasuna', 'intHomeScore': '0', 'intAwayScore': '0', 'intRound': 29, 'homeScored': 46, 'homeConceded': 24, 'homeGD': 22, 'homeWinRate': 0.5, 'awayScored': 33, 'awayConceded': 42, 'awayGD': -9, 'awayWinRate': 0.25, 'homeClassement': 4, 'awayClassement': 14, 'lastHome5GamesScore': 10, 'lastAway5GamesScore': 5, 'homeWins': 8, 'homeDraws': 5, 'homeLosses': 1, 'awayWins': 1, 'awayDraws': 6, 'awayLosses': 6}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Barcelona', 'strAwayTeam': 'Girona', 'intHomeScore': '4', 'intAwayScore': '1', 'intRound': 29, 'homeScored': 78, 'homeConceded': 27, 'homeGD': 51, 'homeWinRate': 0.7142857142857143, 'awayScored': 36, 'awayConceded': 41, 'awayGD': -5, 'awayWinRate': 0.32142857142857145, 'homeClassement': 1, 'awayClassement': 13, 'lastHome5GamesScore': 14, 'lastAway5GamesScore': 5, 'homeWins': 10, 'homeDraws': 0, 'homeLosses': 3, 'awayWins': 3, 'awayDraws': 4, 'awayLosses': 7}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Real Betis', 'strAwayTeam': 'Sevilla', 'intHomeScore': '2', 'intAwayScore': '1', 'intRound': 29, 'homeScored': 38, 'homeConceded': 35, 'homeGD': 3, 'homeWinRate': 0.42857142857142855, 'awayScored': 32, 'awayConceded': 37, 'awayGD': -5, 'awayWinRate': 0.32142857142857145, 'homeClassement': 6, 'awayClassement': 11, 'lastHome5GamesScore': 11, 'lastAway5GamesScore': 7, 'homeWins': 7, 'homeDraws': 5, 'homeLosses': 2, 'awayWins': 4, 'awayDraws': 5, 'awayLosses': 5}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Getafe', 'strAwayTeam': 'Villarreal', 'intHomeScore': '1', 'intAwayScore': '2', 'intRound': 29, 'homeScored': 25, 'homeConceded': 23, 'homeGD': 2, 'homeWinRate': 0.32142857142857145, 'awayScored': 49, 'awayConceded': 38, 'awayGD': 11, 'awayWinRate': 0.4444444444444444, 'homeClassement': 10, 'awayClassement': 5, 'lastHome5GamesScore': 7, 'lastAway5GamesScore': 5, 'homeWins': 4, 'homeDraws': 7, 'homeLosses': 3, 'awayWins': 7, 'awayDraws': 3, 'awayLosses': 4}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Valencia', 'strAwayTeam': 'Mallorca', 'intHomeScore': '1', 'intAwayScore': '0', 'intRound': 29, 'homeScored': 31, 'homeConceded': 46, 'homeGD': -15, 'homeWinRate': 0.21428571428571427, 'awayScored': 28, 'awayConceded': 34, 'awayGD': -6, 'awayWinRate': 0.39285714285714285, 'homeClassement': 16, 'awayClassement': 7, 'lastHome5GamesScore': 7, 'lastAway5GamesScore': 8, 'homeWins': 6, 'homeDraws': 3, 'homeLosses': 5, 'awayWins': 5, 'awayDraws': 2, 'awayLosses': 6}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Celta Vigo', 'strAwayTeam': 'Las Palmas', 'intHomeScore': '1', 'intAwayScore': '1', 'intRound': 29, 'homeScored': 41, 'homeConceded': 41, 'homeGD': 0, 'homeWinRate': 0.39285714285714285, 'awayScored': 32, 'awayConceded': 47, 'awayGD': -15, 'awayWinRate': 0.21428571428571427, 'homeClassement': 8, 'awayClassement': 19, 'lastHome5GamesScore': 7, 'lastAway5GamesScore': 4, 'homeWins': 9, 'homeDraws': 2, 'homeLosses': 3, 'awayWins': 3, 'awayDraws': 2, 'awayLosses': 9}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Vallecano', 'strAwayTeam': 'Espanyol', 'intHomeScore': '0', 'intAwayScore': '4', 'intRound': 30, 'homeScored': 33, 'homeConceded': 31, 'homeGD': 2, 'homeWinRate': 0.3448275862068966, 'awayScored': 27, 'awayConceded': 40, 'awayGD': -13, 'awayWinRate': 0.25, 'homeClassement': 7, 'awayClassement': 16, 'lastHome5GamesScore': 6, 'lastAway5GamesScore': 5, 'homeWins': 5, 'homeDraws': 5, 'homeLosses': 4, 'awayWins': 1, 'awayDraws': 2, 'awayLosses': 10}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Barcelona', 'strAwayTeam': 'Real Betis', 'intHomeScore': '1', 'intAwayScore': '1', 'intRound': 30, 'homeScored': 82, 'homeConceded': 28, 'homeGD': 54, 'homeWinRate': 0.7241379310344828, 'awayScored': 40, 'awayConceded': 36, 'awayGD': 4, 'awayWinRate': 0.4482758620689655, 'homeClassement': 1, 'awayClassement': 6, 'lastHome5GamesScore': 17, 'lastAway5GamesScore': 10, 'homeWins': 11, 'homeDraws': 0, 'homeLosses': 3, 'awayWins': 5, 'awayDraws': 3, 'awayLosses': 6}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Real Madrid', 'strAwayTeam': 'Valencia', 'intHomeScore': '1', 'intAwayScore': '2', 'intRound': 30, 'homeScored': 62, 'homeConceded': 29, 'homeGD': 33, 'homeWinRate': 0.6551724137931034, 'awayScored': 32, 'awayConceded': 46, 'awayGD': -14, 'awayWinRate': 0.2413793103448276, 'homeClassement': 2, 'awayClassement': 15, 'lastHome5GamesScore': 10, 'lastAway5GamesScore': 7, 'homeWins': 12, 'homeDraws': 1, 'homeLosses': 1, 'awayWins': 0, 'awayDraws': 7, 'awayLosses': 7}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Mallorca', 'strAwayTeam': 'Celta Vigo', 'intHomeScore': '1', 'intAwayScore': '2', 'intRound': 30, 'homeScored': 28, 'homeConceded': 35, 'homeGD': -7, 'homeWinRate': 0.3793103448275862, 'awayScored': 42, 'awayConceded': 42, 'awayGD': 0, 'awayWinRate': 0.3793103448275862, 'homeClassement': 9, 'awayClassement': 8, 'lastHome5GamesScore': 5, 'lastAway5GamesScore': 7, 'homeWins': 6, 'homeDraws': 5, 'homeLosses': 4, 'awayWins': 2, 'awayDraws': 4, 'awayLosses': 8}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Girona', 'strAwayTeam': 'Alaves', 'intHomeScore': '0', 'intAwayScore': '1', 'intRound': 30, 'homeScored': 37, 'homeConceded': 45, 'homeGD': -8, 'homeWinRate': 0.3103448275862069, 'awayScored': 32, 'awayConceded': 44, 'awayGD': -12, 'awayWinRate': 0.20689655172413793, 'homeClassement': 13, 'awayClassement': 17, 'lastHome5GamesScore': 5, 'lastAway5GamesScore': 4, 'homeWins': 6, 'homeDraws': 3, 'homeLosses': 5, 'awayWins': 2, 'awayDraws': 5, 'awayLosses': 8}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Las Palmas', 'strAwayTeam': 'Real Sociedad', 'intHomeScore': '1', 'intAwayScore': '3', 'intRound': 30, 'homeScored': 33, 'homeConceded': 48, 'homeGD': -15, 'homeWinRate': 0.20689655172413793, 'awayScored': 27, 'awayConceded': 31, 'awayGD': -4, 'awayWinRate': 0.3793103448275862, 'homeClassement': 19, 'awayClassement': 10, 'lastHome5GamesScore': 4, 'lastAway5GamesScore': 7, 'homeWins': 3, 'homeDraws': 5, 'homeLosses': 6, 'awayWins': 4, 'awayDraws': 3, 'awayLosses': 7}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Villarreal', 'strAwayTeam': 'Athletic Bilbao', 'intHomeScore': '0', 'intAwayScore': '0', 'intRound': 30, 'homeScored': 51, 'homeConceded': 39, 'homeGD': 12, 'homeWinRate': 0.4642857142857143, 'awayScored': 46, 'awayConceded': 24, 'awayGD': 22, 'awayWinRate': 0.4827586206896552, 'homeClassement': 5, 'awayClassement': 4, 'lastHome5GamesScore': 5, 'lastAway5GamesScore': 9, 'homeWins': 5, 'homeDraws': 5, 'homeLosses': 3, 'awayWins': 6, 'awayDraws': 5, 'awayLosses': 3}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Sevilla', 'strAwayTeam': 'Atletico Madrid', 'intHomeScore': '1', 'intAwayScore': '2', 'intRound': 30, 'homeScored': 33, 'homeConceded': 39, 'homeGD': -6, 'homeWinRate': 0.3103448275862069, 'awayScored': 47, 'awayConceded': 23, 'awayGD': 24, 'awayWinRate': 0.5517241379310345, 'homeClassement': 12, 'awayClassement': 3, 'lastHome5GamesScore': 4, 'lastAway5GamesScore': 8, 'homeWins': 5, 'homeDraws': 4, 'homeLosses': 5, 'awayWins': 6, 'awayDraws': 5, 'awayLosses': 3}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Valladolid', 'strAwayTeam': 'Getafe', 'intHomeScore': '0', 'intAwayScore': '4', 'intRound': 30, 'homeScored': 19, 'homeConceded': 65, 'homeGD': -46, 'homeWinRate': 0.13793103448275862, 'awayScored': 26, 'awayConceded': 25, 'awayGD': 1, 'awayWinRate': 0.3103448275862069, 'homeClassement': 20, 'awayClassement': 11, 'lastHome5GamesScore': 4, 'lastAway5GamesScore': 6, 'homeWins': 3, 'homeDraws': 4, 'homeLosses': 7, 'awayWins': 5, 'awayDraws': 2, 'awayLosses': 7}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Leganes', 'strAwayTeam': 'Osasuna', 'intHomeScore': '1', 'intAwayScore': '1', 'intRound': 30, 'homeScored': 28, 'homeConceded': 46, 'homeGD': -18, 'homeWinRate': 0.20689655172413793, 'awayScored': 33, 'awayConceded': 42, 'awayGD': -9, 'awayWinRate': 0.2413793103448276, 'homeClassement': 18, 'awayClassement': 14, 'lastHome5GamesScore': 6, 'lastAway5GamesScore': 4, 'homeWins': 5, 'homeDraws': 2, 'homeLosses': 7, 'awayWins': 1, 'awayDraws': 7, 'awayLosses': 6}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Valencia', 'strAwayTeam': 'Sevilla', 'intHomeScore': '1', 'intAwayScore': '0', 'intRound': 31, 'homeScored': 34, 'homeConceded': 47, 'homeGD': -13, 'homeWinRate': 0.26666666666666666, 'awayScored': 34, 'awayConceded': 41, 'awayGD': -7, 'awayWinRate': 0.3, 'homeClassement': 15, 'awayClassement': 12, 'lastHome5GamesScore': 9, 'lastAway5GamesScore': 4, 'homeWins': 7, 'homeDraws': 3, 'homeLosses': 5, 'awayWins': 4, 'awayDraws': 5, 'awayLosses': 6}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Getafe', 'strAwayTeam': 'Las Palmas', 'intHomeScore': '1', 'intAwayScore': '3', 'intRound': 31, 'homeScored': 30, 'homeConceded': 25, 'homeGD': 5, 'homeWinRate': 0.3333333333333333, 'awayScored': 34, 'awayConceded': 51, 'awayGD': -17, 'awayWinRate': 0.2, 'homeClassement': 11, 'awayClassement': 19, 'lastHome5GamesScore': 9, 'lastAway5GamesScore': 5, 'homeWins': 4, 'homeDraws': 7, 'homeLosses': 4, 'awayWins': 3, 'awayDraws': 3, 'awayLosses': 9}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Leganes', 'strAwayTeam': 'Barcelona', 'intHomeScore': '0', 'intAwayScore': '1', 'intRound': 31, 'homeScored': 29, 'homeConceded': 47, 'homeGD': -18, 'homeWinRate': 0.2, 'awayScored': 83, 'awayConceded': 29, 'awayGD': 54, 'awayWinRate': 0.7, 'homeClassement': 18, 'awayClassement': 1, 'lastHome5GamesScore': 7, 'lastAway5GamesScore': 16, 'homeWins': 5, 'homeDraws': 3, 'homeLosses': 7, 'awayWins': 10, 'awayDraws': 3, 'awayLosses': 2}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Real Sociedad', 'strAwayTeam': 'Mallorca', 'intHomeScore': '0', 'intAwayScore': '2', 'intRound': 31, 'homeScored': 30, 'homeConceded': 32, 'homeGD': -2, 'homeWinRate': 0.4, 'awayScored': 29, 'awayConceded': 37, 'awayGD': -8, 'awayWinRate': 0.36666666666666664, 'homeClassement': 8, 'awayClassement': 10, 'lastHome5GamesScore': 7, 'lastAway5GamesScore': 5, 'homeWins': 7, 'homeDraws': 2, 'homeLosses': 6, 'awayWins': 5, 'awayDraws': 2, 'awayLosses': 7}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Celta Vigo', 'strAwayTeam': 'Espanyol', 'intHomeScore': '0', 'intAwayScore': '2', 'intRound': 31, 'homeScored': 44, 'homeConceded': 43, 'homeGD': 1, 'homeWinRate': 0.4, 'awayScored': 31, 'awayConceded': 40, 'awayGD': -9, 'awayWinRate': 0.27586206896551724, 'homeClassement': 7, 'awayClassement': 16, 'lastHome5GamesScore': 8, 'lastAway5GamesScore': 8, 'homeWins': 9, 'homeDraws': 3, 'homeLosses': 3, 'awayWins': 2, 'awayDraws': 2, 'awayLosses': 10}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Real Betis', 'strAwayTeam': 'Villarreal', 'intHomeScore': '1', 'intAwayScore': '2', 'intRound': 31, 'homeScored': 41, 'homeConceded': 37, 'homeGD': 4, 'homeWinRate': 0.43333333333333335, 'awayScored': 51, 'awayConceded': 39, 'awayGD': 12, 'awayWinRate': 0.4482758620689655, 'homeClassement': 6, 'awayClassement': 5, 'lastHome5GamesScore': 9, 'lastAway5GamesScore': 4, 'homeWins': 8, 'homeDraws': 5, 'homeLosses': 2, 'awayWins': 8, 'awayDraws': 3, 'awayLosses': 4}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Alaves', 'strAwayTeam': 'Real Madrid', 'intHomeScore': '0', 'intAwayScore': '1', 'intRound': 31, 'homeScored': 33, 'homeConceded': 44, 'homeGD': -11, 'homeWinRate': 0.23333333333333334, 'awayScored': 63, 'awayConceded': 31, 'awayGD': 32, 'awayWinRate': 0.6333333333333333, 'homeClassement': 17, 'awayClassement': 2, 'lastHome5GamesScore': 5, 'lastAway5GamesScore': 9, 'homeWins': 4, 'homeDraws': 4, 'homeLosses': 6, 'awayWins': 7, 'awayDraws': 5, 'awayLosses': 3}
# {'strLeague': 'Spanish La Liga', 'strSeason': '2024-2025', 'strHomeTeam': 'Osasuna', 'strAwayTeam': 'Girona', 'intHomeScore': '2', 'intAwayScore': '1', 'intRound': 31, 'homeScored': 34, 'homeConceded': 43, 'homeGD': -9, 'homeWinRate': 0.23333333333333334, 'awayScored': 37, 'awayConceded': 46, 'awayGD': -9, 'awayWinRate': 0.3, 'homeClassement': 13, 'awayClassement': 14, 'lastHome5GamesScore': 5, 'lastAway5GamesScore': 5, 'homeWins': 6, 'homeDraws': 6, 'homeLosses': 3, 'awayWins': 3, 'awayDraws': 4, 'awayLosses': 8}
# Data saved to liga_data_with_home_away_stats.csv
